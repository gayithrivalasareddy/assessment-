# %% [markdown]
# <a href="https://www.viharatech.com"><img src="https://miro.medium.com/v2/resize:fit:828/format:webp/1*on2Bpj6A5gfd-CzaFOAZRA.jpeg"></a>
#
#
# - `Welcome to our interactive learning session! In this Jupyter notebook, you'll find a series of questions related to Python Concept. To maximize your learning, please write Python code in the cell below each question and execute it. This hands-on practice will help reinforce your understanding of the concepts. Feel free to reach out if you have any questions or need assistance. Happy coding! 💻🐍 `

# %% [raw]
# 1 . Print the input text without vowels
#
# input = 'hai'
#
# Expected output = h

# %%
str = "science"
vowels = ['a','e','i','o','u','A','I','E','O','U']
result = ""
for i in range (len(str)):
  if str [i]not in vowels:
    result = result +str[i]
    print ("\nafter removing vowels:", result)
# Out:
# after removing vowels: s
#
# after removing vowels: sc
#
# after removing vowels: scn
#
# after removing vowels: scnc

# %% [raw]
# 3 . print each valu from the list with its index
#
#
# input = [10,11,50,34]
#
# Expected output = [100 , 111 , 502 , 343]

# %% [markdown]
# **bold text**

# %%
input = [10,11,50,34]
for index,value in enumerate (input):
  print(f"index:{index},value:{value}")
# Out:
# index:0,value:10
# index:1,value:11
# index:2,value:50
# index:3,value:34

# %% [raw]
# 4 . This is a Python Program to print all integers that aren’t divisible by either 2 or 3 and lies between 1 and 50.

# %%
for i in range (1,51):
  if i % 2 !=0 and i % 3 !=0:
    print (i)
# Out:
# 1
# 5
# 7
# 11
# 13
# 17
# 19
# 23
# 25
# 29
# 31
# 35
# 37
# 41
# 43
# 47
# 49

# %% [raw]
# 5 . The program takes in an integer and prints the smallest divisor of the integer.

# %%
first_num = int (input("56"))
my_list = []
print ("56")
print (first_num)
 for i in range(2,first_num+1):
  if (first_num%i==0)
  my_list.append (i)
my_list.sort()
print ("the smallest divisor is :")
print (my_list(0))
# Out:
#   File "<ipython-input-30-b302c856a46b>", line 5
#     for i in range(2,first_num+1):
#     ^
# IndentationError: unexpected indent

# %% [raw]
# **bold text**[link text](https://)6 . Write a Python program to check if it is a strong number or not .

# %%
a = ("data science")
print ("uppercase:",a.upper())
print ("lowercase:",a.lower())
# Out:
# uppercase: DATA SCIENCE
# lowercase: data science

# %% [raw]
# 8 . Write a Python program to remove spaces from a given string
#
# - input = united states
# - output = unitedstates

# %%
b = ("united states")
text_no_spaces=b.replace("","")
print ("original string:",b)
print ("string without spaces:",text_no_spaces)
# Out:
# original string: united states
# string without spaces: united states

# %% [raw]
# 9 . Write a Python program to capitalize first and last letters of each word of a given string.

# %%
s = "python"
print("string before:", s)
a = s.split()
res = []
for i in a :
  x =i[0].upper()+i[1:-1]+i[-1].upper()
  res.append(x)
  res = "".join(res)
  print("string after:",res)
# Out:
# string before: python
# string after: PythoN

# %%
str = "hello world"
print("string before:",str)
string =""
for i in str.title(). split():
  string +=(i[:-1]+ i [-1].upper())+ ''
  print ("string after:",string.strip())
# Out:
# string before: hello world
# string after: HellO
# string after: HellOWorlD

# %% [raw]
# 10 . write a python program to find length of a string but should not use len keyword

# %%
def findlength (str):
  counter = 0
  for i in str:
    counter +=1
    return counter

str = "java"
print(len(str))
# Out:
# 4
